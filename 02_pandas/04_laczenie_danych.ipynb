# %% [markdown]
# <a href="https://colab.research.google.com/github/Oliwer1992/kurs/blob/main/02_pandas/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ### Wczytanie danych

# %%
def fetch_financial_data(company='AMZN'):
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2025-07-18 to 2020-07-20
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2025-07-18 to 2020-07-20
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.head()
# Out:
#                Open    High       Low   Close    Volume
# Date
# 2025-07-18  210.870  211.79  209.7045  211.18  48974591
# 2025-07-17  210.570  211.80  209.5900  210.02  48068141
# 2025-07-16  210.295  212.40  208.6400  210.16  47490532
# 2025-07-15  209.220  211.89  208.9200  209.11  42296339
# 2025-07-14  209.925  210.91  207.5400  208.62  38840111

# %% [markdown]
# ### Preprocesing

# %%
apple.columns = ['apple_' + col.lower() for col in apple.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]
uber.columns = ['uber_' + col.lower() for col in uber.columns ]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2025-07-18     210.870      211.79   209.7045       211.18      48974591
# 2025-07-17     210.570      211.80   209.5900       210.02      48068141
# 2025-07-16     210.295      212.40   208.6400       210.16      47490532
# 2025-07-15     209.220      211.89   208.9200       209.11      42296339
# 2025-07-14     209.925      210.91   207.5400       208.62      38840111

# %%
google.head()
# Out:
#             google_open  google_high  google_low  google_close  google_volume
# Date
# 2025-07-18      185.400      186.420      183.71        185.06       34014509
# 2025-07-17      182.140      184.060      180.48        183.58       31992565
# 2025-07-16      183.235      184.327      182.03        182.97       33104193
# 2025-07-15      182.810      184.220      181.60        182.00       33448251
# 2025-07-14      181.010      183.670      179.68        181.56       32536632

# %% [markdown]
# ### Konkatencja danych

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1)

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}') # Zaokrągla dane do dwóch miejsc po przecinku
df.describe().T
# Out:
#                 count        mean         std         min         25%  \
# apple_open    1256.00      167.29       36.63       88.56      140.17
# apple_high    1256.00      169.16       36.88       90.49      141.70
# apple_low     1256.00      165.55       36.45       86.77      138.42
# apple_close   1256.00      167.45       36.71       90.15      140.24
# apple_volume  1256.00 79632132.42 41456069.57 23260251.00 51739837.25
# amazon_open   1256.00      157.15       34.68       82.80      132.11
# amazon_high   1256.00      159.05       34.80       83.48      133.66
# amazon_low    1256.00      155.10       34.49       81.43      130.48
# amazon_close  1256.00      157.11       34.67       81.82      132.12
# amazon_volume 1256.00 62086391.32 29324191.80 15007497.00 42335961.25
# google_open   1256.00      130.00       31.29       69.88      104.27
# google_high   1256.00      131.51       31.54       71.64      105.72
# google_low    1256.00      128.58       31.00       69.85      103.33
# google_close  1256.00      130.06       31.26       70.21      104.46
# google_volume 1256.00 32220758.39 13708610.44  9346519.00 23369565.50
# uber_open     1256.00       50.26       18.41       20.37       34.15
# uber_high     1256.00       51.15       18.58       21.13       34.80
# uber_low      1256.00       49.36       18.19       19.89       33.34
# uber_close    1256.00       50.27       18.39       20.46       34.13
# uber_volume   1256.00 23779590.53 16286961.82  5200356.00 15601375.00
#
#                       50%         75%          max
# apple_open         165.17      190.87       257.91
# apple_high         166.88      192.68       259.81
# apple_low          163.72      189.65       257.35
# apple_close        165.01      191.11       258.74
# apple_volume  69718430.50 93996238.75 384545982.00
# amazon_open        160.53      178.20       239.01
# amazon_high        162.35      180.35       242.52
# amazon_low         158.62      176.31       238.03
# amazon_close       160.46      178.64       242.06
# amazon_volume 55551700.50 73427252.50 272661720.00
# google_open        130.83      152.23       203.39
# google_high        132.25      154.29       207.05
# google_low         129.27      150.09       202.81
# google_close       130.75      151.71       206.38
# google_volume 28871750.50 36635166.25 127747554.00
# uber_open           46.55       66.13        97.50
# uber_high           47.51       67.33        97.72
# uber_low            45.92       65.20        96.10
# uber_close          46.59       66.10        97.48
# uber_volume   20113970.00 27687859.00 364261230.00

# %%
df.corr() # Współczynniki koleracji
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.55
# apple_high           1.00        1.00       1.00         1.00         -0.53
# apple_low            1.00        1.00       1.00         1.00         -0.56
# apple_close          1.00        1.00       1.00         1.00         -0.55
# apple_volume        -0.55       -0.53      -0.56        -0.55          1.00
# amazon_open          0.54        0.54       0.54         0.54         -0.11
# amazon_high          0.54        0.54       0.54         0.54         -0.11
# amazon_low           0.54        0.54       0.54         0.54         -0.13
# amazon_close         0.54        0.54       0.54         0.54         -0.12
# amazon_volume       -0.52       -0.51      -0.53        -0.52          0.60
# google_open          0.87        0.87       0.88         0.87         -0.50
# google_high          0.88        0.88       0.88         0.88         -0.49
# google_low           0.87        0.87       0.87         0.87         -0.50
# google_close         0.87        0.87       0.87         0.87         -0.50
# google_volume       -0.11       -0.11      -0.12        -0.12          0.30
# uber_open            0.66        0.66       0.66         0.66         -0.36
# uber_high            0.66        0.66       0.66         0.66         -0.36
# uber_low             0.66        0.66       0.66         0.66         -0.36
# uber_close           0.66        0.66       0.66         0.66         -0.36
# uber_volume         -0.03       -0.03      -0.03        -0.03          0.12
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.54         0.54        0.54          0.54
# apple_high            0.54         0.54        0.54          0.54
# apple_low             0.54         0.54        0.54          0.54
# apple_close           0.54         0.54        0.54          0.54
# apple_volume         -0.11        -0.11       -0.13         -0.12
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.33        -0.32       -0.34         -0.33
# google_open           0.73         0.73        0.73          0.73
# google_high           0.73         0.73        0.73          0.73
# google_low            0.73         0.73        0.73          0.73
# google_close          0.73         0.73        0.73          0.73
# google_volume        -0.11        -0.10       -0.12         -0.11
# uber_open             0.79         0.79        0.79          0.79
# uber_high             0.79         0.79        0.79          0.79
# uber_low              0.79         0.79        0.79          0.79
# uber_close            0.79         0.79        0.79          0.79
# uber_volume          -0.09        -0.09       -0.09         -0.09
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.52         0.87         0.88        0.87
# apple_high             -0.51         0.87         0.88        0.87
# apple_low              -0.53         0.88         0.88        0.87
# apple_close            -0.52         0.87         0.88        0.87
# apple_volume            0.60        -0.50        -0.49       -0.50
# amazon_open            -0.33         0.73         0.73        0.73
# amazon_high            -0.32         0.73         0.73        0.73
# amazon_low             -0.34         0.73         0.73        0.73
# amazon_close           -0.33         0.73         0.73        0.73
# amazon_volume           1.00        -0.51        -0.51       -0.52
# google_open            -0.51         1.00         1.00        1.00
# google_high            -0.51         1.00         1.00        1.00
# google_low             -0.52         1.00         1.00        1.00
# google_close           -0.51         1.00         1.00        1.00
# google_volume           0.45        -0.14        -0.13       -0.16
# uber_open              -0.47         0.73         0.73        0.73
# uber_high              -0.47         0.73         0.73        0.73
# uber_low               -0.48         0.73         0.73        0.73
# uber_close             -0.47         0.73         0.73        0.73
# uber_volume             0.22        -0.04        -0.04       -0.05
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.87          -0.11       0.66       0.66      0.66
# apple_high             0.87          -0.11       0.66       0.66      0.66
# apple_low              0.87          -0.12       0.66       0.66      0.66
# apple_close            0.87          -0.12       0.66       0.66      0.66
# apple_volume          -0.50           0.30      -0.36      -0.36     -0.36
# amazon_open            0.73          -0.11       0.79       0.79      0.79
# amazon_high            0.73          -0.10       0.79       0.79      0.79
# amazon_low             0.73          -0.12       0.79       0.79      0.79
# amazon_close           0.73          -0.11       0.79       0.79      0.79
# amazon_volume         -0.51           0.45      -0.47      -0.47     -0.48
# google_open            1.00          -0.14       0.73       0.73      0.73
# google_high            1.00          -0.13       0.73       0.73      0.73
# google_low             1.00          -0.16       0.73       0.73      0.73
# google_close           1.00          -0.15       0.73       0.73      0.73
# google_volume         -0.15           1.00      -0.09      -0.09     -0.10
# uber_open              0.73          -0.09       1.00       1.00      1.00
# uber_high              0.73          -0.09       1.00       1.00      1.00
# uber_low               0.73          -0.10       1.00       1.00      1.00
# uber_close             0.73          -0.09       1.00       1.00      1.00
# uber_volume           -0.04           0.20      -0.16      -0.15     -0.17
#
#                uber_close  uber_volume
# apple_open           0.66        -0.03
# apple_high           0.66        -0.03
# apple_low            0.66        -0.03
# apple_close          0.66        -0.03
# apple_volume        -0.36         0.12
# amazon_open          0.79        -0.09
# amazon_high          0.79        -0.09
# amazon_low           0.79        -0.09
# amazon_close         0.79        -0.09
# amazon_volume       -0.47         0.22
# google_open          0.73        -0.04
# google_high          0.73        -0.04
# google_low           0.73        -0.05
# google_close         0.73        -0.04
# google_volume       -0.09         0.20
# uber_open            1.00        -0.16
# uber_high            1.00        -0.15
# uber_low             1.00        -0.17
# uber_close           1.00        -0.16
# uber_volume         -0.16         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')] # Zaznaczamy tylko kolumny close
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes] # Wycinamy kolumny close
# Out:
#             apple_close  amazon_close  google_close  uber_close
# Date
# 2025-07-18       211.18        226.13        185.06       90.59
# 2025-07-17       210.02        223.88        183.58       90.50
# 2025-07-16       210.16        223.19        182.97       90.75
# 2025-07-15       209.11        226.35        182.00       92.21
# 2025-07-14       208.62        225.69        181.56       93.89
# ...                 ...           ...           ...         ...
# 2020-07-24        90.15        150.44         75.14       31.18
# 2020-07-23        90.37        149.33         75.56       32.17
# 2020-07-22        94.68        155.00         77.96       32.66
# 2020-07-21        94.41        156.91         77.52       32.55
# 2020-07-20        95.74        159.84         77.91       33.66
#
# [1256 rows x 4 columns]

# %%
df[closes].corr() # Obliczamy współczynniki korelacji dla kolumn close
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00          0